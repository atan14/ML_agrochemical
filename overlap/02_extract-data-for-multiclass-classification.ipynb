# %% [markdown]
# Data is extracted from chembl_24.db (from [ChEMBL database](https://www.ebi.ac.uk/chembl/downloads)). We then parse the data and save data into pickle file for use in deep learning of the structures.

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import os
import sqlite3
import pickle
import rdkit.Chem as chem

from sklearn.utils import shuffle

# %% [markdown]
# Connect database using sqlite3 package

# %%
db = sqlite3.connect('chembl_24.db')
c = db.cursor()

# %% [markdown]
# Import doc_id from chembl_24.db, then use doc_id to extract molregno (unique internal Chembl compound identifier)

# %%
categories = ['%toxin%', '%fungicidal%', '%nematicidal%', '%herbicidal%', '%insecticidal%']

# %%
molregno = dict.fromkeys(categories, None)
for cat in categories:
    # extract doc_id from assays that contain agrochemical and non-agrochemical keywords
    doc_id = c.execute("SELECT doc_id FROM assays where description like '%s'" %cat).fetchall()
    doc_id = [i[0] for i in doc_id]
    
    # extract unique compound identifier from doc_id
    molregno[cat] = c.execute("SELECT molregno FROM compound_records WHERE doc_id IN " + str(tuple(doc_id))).fetchall()
    molregno[cat] = [i[0] for i in molregno[cat]]
    print ("%s" %cat[1:-1], ":", len(molregno[cat]))
# Out:
# toxin : 541388
# fungicidal : 4678
# nematicidal : 555
# herbicidal : 3715
# insecticidal : 5987

# %% [markdown]
# Print number of overlapping data

# %%
for i, cat_a in enumerate(categories):
    for j, cat_b in enumerate(categories):
        if (i < j):
            intersection = list(set(molregno[cat_a])&set(molregno[cat_b]))
            print (cat_a, cat_b, len(intersection))
# Out:
# %toxin% %fungicidal% 285
# %toxin% %nematicidal% 163
# %toxin% %herbicidal% 156
# %toxin% %insecticidal% 513
# %fungicidal% %nematicidal% 28
# %fungicidal% %herbicidal% 131
# %fungicidal% %insecticidal% 283
# %nematicidal% %herbicidal% 17
# %nematicidal% %insecticidal% 86
# %herbicidal% %insecticidal% 113

# %% [markdown]
# Dispose data that overlaps

# %%
# %%time
for i, cat_a in enumerate(categories):
    for j, cat_b in enumerate(categories):
        if (i < j):
            intersection = list(set(molregno[cat_a])&set(molregno[cat_b]))
            molregno[cat_a] = [x for x in molregno[cat_a] if x not in intersection]
# Out:
# %toxin% %fungicidal% 285
# %toxin% %nematicidal% 141
# %toxin% %herbicidal% 128
# %toxin% %insecticidal% 410
# %fungicidal% %nematicidal% 28
# %fungicidal% %herbicidal% 127
# %fungicidal% %insecticidal% 231
# %nematicidal% %herbicidal% 17
# %nematicidal% %insecticidal% 80
# %herbicidal% %insecticidal% 113
# CPU times: user 6.53 s, sys: 101 ms, total: 6.63 s
# Wall time: 6.72 s

# %% [markdown]
# Then, we get canonical smiles string and compound properties from molregno compound identifier. We check to make sure the smiles strings and properties are mapped exactly.
#
# - mw_freebase = Molecular weight of parent compound
# - alogp = Calculated ALogP
# - hba = number of hydrogen bond acceptors
# - hbd = number of hydrogen bond donors
# - psa = polar surface area
# - rtb = number of rotatable bonds
# - acd_logp = calculated octanol/water partition coefficient using ACDlabs v12.01
# - acd_logd = calculated octanol/water distribution coefficient at pH 7.4 using ACDlabs v12.01
# - full_mwt = molecular weight of the full compound including any salts
# - aromatic_rings = number of aromatic rings
# - heavy_atoms = number of heavy (non-hydrogen) atoms
# - qed_weighted = weighted quantitative estimate of drug likeness
# - mw_monoisotopic = monoisotopic parent molecular weight
# - hba_lipinski = number of hydrogen bond acceptros calculated according to the Lipinski's original rules (i.e. N + O count)
# - hbd_lipinski = number of hydrogen bond donors calculated according to the Lipinski's original rules (i.e., NH + OH count)

# %%
smiles_string = dict.fromkeys(categories, None)
mw_freebase_dict = dict.fromkeys(categories, None)
alogp_dict = dict.fromkeys(categories, None)
hba_dict = dict.fromkeys(categories, None)
hbd_dict = dict.fromkeys(categories, None)
psa_dict = dict.fromkeys(categories, None)
rtb_dict = dict.fromkeys(categories, None)
acd_logp_dict = dict.fromkeys(categories, None)
acd_logd_dict = dict.fromkeys(categories, None)
full_mwt_dict = dict.fromkeys(categories, None)
aromatic_rings_dict = dict.fromkeys(categories, None)
heavy_atoms_dict = dict.fromkeys(categories, None)
qed_weighted_dict = dict.fromkeys(categories, None)
mw_monoisotopic_dict = dict.fromkeys(categories, None)
hba_lipinski_dict = dict.fromkeys(categories, None)
hbd_lipinski_dict = dict.fromkeys(categories, None)

# %%
for cat in molregno:
    smiles_string[cat], mw_freebase_dict[cat], alogp_dict[cat], hba_dict[cat], hbd_dict[cat], psa_dict[cat] = [], [], [], [], [], []
    rtb_dict[cat], acd_logp_dict[cat], acd_logd_dict[cat], full_mwt_dict[cat], aromatic_rings_dict[cat], heavy_atoms_dict[cat] = [], [], [], [], [], []
    qed_weighted_dict[cat], mw_monoisotopic_dict[cat], hba_lipinski_dict[cat], hbd_lipinski_dict[cat] = [], [], [], []
    for num in molregno[cat]:
        smile = c.execute("SELECT canonical_smiles FROM compound_structures WHERE molregno = " + str(num)).fetchall()
        properties = c.execute("SELECT * FROM compound_properties WHERE molregno = " + str(num)).fetchall()
        if not smile or not properties:
            molregno[cat].remove(num)
        else:
            properties = properties[0]
            smiles_string[cat].append(smile[0])
            
            # assign properties to corresponding dictionaries
            mw_freebase_dict[cat].append(properties[1])
            alogp_dict[cat].append(properties[2])
            hba_dict[cat].append(properties[3])
            hbd_dict[cat].append(properties[4])
            psa_dict[cat].append(properties[5])
            rtb_dict[cat].append(properties[6])
            acd_logp_dict[cat].append(properties[11])
            acd_logd_dict[cat].append(properties[12])
            full_mwt_dict[cat].append(properties[14])
            aromatic_rings_dict[cat].append(properties[15])
            heavy_atoms_dict[cat].append(properties[16])
            qed_weighted_dict[cat].append(properties[17])
            mw_monoisotopic_dict[cat].append(properties[18])
            hba_lipinski_dict[cat].append(properties[20])
            hbd_lipinski_dict[cat].append(properties[21])

# %% [markdown]
# Convert smiles string and the properties into a long list and then create another list containing their corresponding categorical name

# %%
canonical_smiles, label = [], []
mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],
for cat in smiles_string:
    canonical_smiles += smiles_string[cat]
    label += [cat[1:-1]]*len(smiles_string[cat])
    
    mw_freebase += mw_freebase_dict[cat]
    alogp += alogp_dict[cat]
    hba += hba_dict[cat]
    hbd += hbd_dict[cat]
    psa += psa_dict[cat]
    rtb += rtb_dict[cat]
    acd_logp += acd_logp_dict[cat]
    acd_logd += acd_logd_dict[cat]
    full_mwt += full_mwt_dict[cat]
    aromatic_rings += aromatic_rings_dict[cat]
    heavy_atoms += heavy_atoms_dict[cat]
    qed_weighted += qed_weighted_dict[cat]
    mw_monoisotopic += mw_monoisotopic_dict[cat]
    hba_lipinski += hba_lipinski_dict[cat]
    hbd_lipinski += hbd_lipinski_dict[cat]

# %% [markdown]
# Stack the two lists together

# %%
data = np.column_stack((canonical_smiles, label, mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski))

# %% [markdown]
# Convert data into pandas dataframe

# %%
data = pd.DataFrame(data, columns=['smiles', 'category', 'mw_freebase', 'alogp', 'hba', 'hbd', 'psa', 'rtb', 'acd_logp', 'acd_logd', 'full_mwt', 'aromatic_rings', 'heavy_atoms', 'qed_weighted', 'mw_monoisotopic', 'hba_lipinski', 'hbd_lipinski'])

# %% [markdown]
# Add a column containing RDKit Molecule class

# %%
# %%time
data['mol'] = data['smiles'].apply(chem.MolFromSmiles)
# Out:
# CPU times: user 3min 8s, sys: 5.9 s, total: 3min 13s
# Wall time: 3min 16s

# %% [markdown]
# Add another column that differentiates non-agrochemical and agrochemical category

# %%
def class_label(x):
    if x == 'toxin':
        return 4
    elif x == 'herbicidal':
        return 0
    elif x == 'insecticidal':
        return 1
    elif x == 'nematicidal':
        return 2
    elif x == 'fungicidal':
        return 3

# %%
# %%time
data['agrochemical'] = data['category'].apply(class_label)
# Out:
# CPU times: user 201 ms, sys: 22 ms, total: 223 ms
# Wall time: 223 ms

# %% [markdown]
# Remove null values

# %%
data.dropna(axis=0, inplace=True)

# %% [markdown]
# Reset index

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Count number of compounds in agrochemical and non-agrochemical category

# %%
data['agrochemical'].value_counts()
# Out:
# 4    529239
# 1      5834
# 3      3822
# 0      3526
# 2       405
# Name: agrochemical, dtype: int64

# %%
data
# Out:
#                                                    smiles      category  \
# 0       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 1       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 2       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 3       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 4       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 5       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 6       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 7       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 8       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 9       CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 10      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 11      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 12      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 13      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 14      CC(C)[C@@H]1OC(=O)[C@@H](C)N(O)C(=O)[C@@H]2CCC...         toxin
# 15      CC(C)[C@@H]1OC(=O)[C@@H](C)N(O)C(=O)[C@@H]2CCC...         toxin
# 16      CC[C@H](C)C[C@H]1CC[C@@H](O[C@@H]1C)[C@](C)(O)...         toxin
# 17      CC(C)[C@@H]1OC(=O)[C@@H](C)N(O)C(=O)[C@@H]2CCC...         toxin
# 18      CC(C)[C@@H]1OC(=O)[C@@H](C)N(O)C(=O)[C@@H]2CCC...         toxin
# 19      CC(C)[C@@H]1OC(=O)[C@@H](C)N(O)C(=O)[C@@H]2CCC...         toxin
# 20      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 21      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 22      CC[C@@H](C)CC1CCC(O)(OC1C)[C@](C)(O)C(=O)NC2[C...         toxin
# 23      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 24      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 25      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 26      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 27      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 28      CC[C@H](C)C[C@H]1CC[C@@](O)(O[C@@H]1C)[C@](C)(...         toxin
# 29      COc1ccc(cc1OC)C2CCC(OCc3ccc(Cn4c(C)nc5ccccc45)...         toxin
# ...                                                   ...           ...
# 542796                            CC(=O)\C=C\c1cccc(O)c1O  insecticidal
# 542797                            CC(=O)\C=C\c1cc(O)ccc1O  insecticidal
# 542798                     COc1cc(\C=C\C(=O)C)ccc1OC(=O)C  insecticidal
# 542799                          COc1ccc(\C=C\C(=O)C)cc1OC  insecticidal
# 542800  COc1cc(\C=C\C(=O)C)ccc1OC2OC(COC(=O)C)C(OC(=O)...  insecticidal
# 542801        COc1cc(\C=C\C(=O)C)ccc1OC2OC(CO)C(O)C(O)C2O  insecticidal
# 542802  CC(C)CCC[C@@H](C)CCC[C@@H](C)CCC[C@]1(C)CCc2c(...  insecticidal
# 542803                     OC[C@H](O)[C@H]1OC(=O)C(=C1O)O  insecticidal
# 542804                           COc1cc(\C=C\C(=O)C)ccc1O  insecticidal
# 542805                  Cc1c(C)c2OC(C)(CCc2c(C)c1O)C(=O)O  insecticidal
# 542806  COc1cc(\C=C\C(=O)CC(=O)\C=C\c2ccc(O)c(OC)c2)ccc1O  insecticidal
# 542807                           COc1cccc(\C=C\C(=O)C)c1O  insecticidal
# 542808                                  CC(=O)C#Cc1ccccc1  insecticidal
# 542809                                CC(=O)\C=C\c1ccccc1  insecticidal
# 542810                                   CC(=O)CCc1ccccc1  insecticidal
# 542811                                COc1cc(\C=C\C)ccc1O  insecticidal
# 542812                   COc1cc(\C=C\C(=O)C)ccc1OCC=C(C)C  insecticidal
# 542813                   COc1cccc(\C=C\C(=O)C)c1OCC=C(C)C  insecticidal
# 542814                   COc1ccc(\C=C\C(=O)C)cc1OCC=C(C)C  insecticidal
# 542815  COc1cc(\C=C\C(=O)C(=Cc2ccc3C(=O)N(C4CCC(=O)NC4...  insecticidal
# 542816  COc1cc(\C=C\C(=O)\C=C\c2ccc3C(=O)N(C4CCC(=O)NC...  insecticidal
# 542817      COc1cc(\C=C\C(=O)\C=C\c2nc3c(C)cccc3n2C)ccc1O  insecticidal
# 542818  COc1cc(\C=C\C(=O)CC(=O)C(C)c2ccc(CC(C)C)cc2)ccc1O  insecticidal
# 542819                         CC(C)Cc1ccc(cc1)C(C)C(=O)O  insecticidal
# 542820                CCCCC\C=C\C(=O)\C=C\c1ccc(O)c(OC)c1  insecticidal
# 542821                   COc1cc(ccc1O)C(CC(=O)C)Sc2ccccc2  insecticidal
# 542822                 COc1ccc(\C=C\C(=O)C)c(OCC=C(C)C)c1  insecticidal
# 542823      COc1cc(\C=C\C(=O)\C=C\c2nc3cc(C)ccc3n2C)ccc1O  insecticidal
# 542824      COc1ccc(\C=C\C(=O)\C=C\c2nc3cc(C)ccc3n2C)cc1O  insecticidal
# 542825      COc1ccc(\C=C\C(=O)\C=C\c2nc3cc(O)ccc3n2C)cc1O  insecticidal
#
#        mw_freebase alogp hba hbd     psa rtb acd_logp acd_logd full_mwt  \
# 0           840.97 -0.94  15   8  279.95   7     0.74      0.7   840.97
# 1              839  -0.7  14   7  259.72   7     1.18     1.15      839
# 2           782.89 -2.06  14   8  268.51   6    -0.15    -0.18   782.89
# 3           839.98 -0.05  14   7  267.92   7     1.94     1.88   839.98
# 4           885.03 -1.03  15   9  305.81  11     1.75     1.67   885.03
# 542820              1          20         0.57         274.157            3
# 542821              2          21         0.81         302.098            3
# 542822              1          19         0.58         260.141            3
# 542823              3          26         0.71         348.147            5
# 542824              3          26         0.71         348.147            5
# 542825              3          26         0.69         350.127            6
#
#        hbd_lipinski                                            mol  \
# 0                 8  <rdkit.Chem.rdchem.Mol object at 0x12983da80>
# 1                 7  <rdkit.Chem.rdchem.Mol object at 0x12983dd00>
# 2                 8  <rdkit.Chem.rdchem.Mol object at 0x12983dc10>
# 3                 7  <rdkit.Chem.rdchem.Mol object at 0x12983dda0>
# 4                 9  <rdkit.Chem.rdchem.Mol object at 0x12983dcb0>
# 5                 6  <rdkit.Chem.rdchem.Mol object at 0x12983de40>
# 6                 8  <rdkit.Chem.rdchem.Mol object at 0x12983dd50>
# 7                 7  <rdkit.Chem.rdchem.Mol object at 0x12983dee0>
# 8                 7  <rdkit.Chem.rdchem.Mol object at 0x12983ddf0>
# 9                 7  <rdkit.Chem.rdchem.Mol object at 0x12983df80>
# 10                7  <rdkit.Chem.rdchem.Mol object at 0x12983de90>
# 11                7  <rdkit.Chem.rdchem.Mol object at 0x12983df30>
# 12                8  <rdkit.Chem.rdchem.Mol object at 0x129873120>
# 13                6  <rdkit.Chem.rdchem.Mol object at 0x129873030>
# 14                7  <rdkit.Chem.rdchem.Mol object at 0x129873080>
# 15                7  <rdkit.Chem.rdchem.Mol object at 0x129873170>
# 16                7  <rdkit.Chem.rdchem.Mol object at 0x129873210>
# 17                7  <rdkit.Chem.rdchem.Mol object at 0x1298731c0>
# 18                7  <rdkit.Chem.rdchem.Mol object at 0x1a3902da0>
# 19                6  <rdkit.Chem.rdchem.Mol object at 0x1a3902df0>
# 20                8  <rdkit.Chem.rdchem.Mol object at 0x1a3902e40>
# 21                8  <rdkit.Chem.rdchem.Mol object at 0x1a3902e90>
# 22                8  <rdkit.Chem.rdchem.Mol object at 0x1a3902ee0>
# 23                6  <rdkit.Chem.rdchem.Mol object at 0x1a3902f30>
# 24                7  <rdkit.Chem.rdchem.Mol object at 0x1a3902f80>
# 25               10  <rdkit.Chem.rdchem.Mol object at 0x1a7d17030>
# 26                8  <rdkit.Chem.rdchem.Mol object at 0x1a7d17080>
# 27                7  <rdkit.Chem.rdchem.Mol object at 0x1a7d170d0>
# 28                8  <rdkit.Chem.rdchem.Mol object at 0x1a7d17120>
# 29                0  <rdkit.Chem.rdchem.Mol object at 0x1a7d17170>
# ...             ...                                            ...
# 542796            2  <rdkit.Chem.rdchem.Mol object at 0x1304f0620>
# 542797            2  <rdkit.Chem.rdchem.Mol object at 0x1304f0670>
# 542798            0  <rdkit.Chem.rdchem.Mol object at 0x1304f06c0>
# 542799            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0710>
# 542800            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0760>
# 542801            4  <rdkit.Chem.rdchem.Mol object at 0x1304f07b0>
# 542802            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0800>
# 542803            4  <rdkit.Chem.rdchem.Mol object at 0x1304f0850>
# 542804            1  <rdkit.Chem.rdchem.Mol object at 0x1304f08a0>
# 542805            2  <rdkit.Chem.rdchem.Mol object at 0x1304f08f0>
# 542806            2  <rdkit.Chem.rdchem.Mol object at 0x1304f0940>
# 542807            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0990>
# 542808            0  <rdkit.Chem.rdchem.Mol object at 0x1304f09e0>
# 542809            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0a30>
# 542810            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0a80>
# 542811            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0ad0>
# 542812            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0b20>
# 542813            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0b70>
# 542814            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0bc0>
# 542815            3  <rdkit.Chem.rdchem.Mol object at 0x1304f0c10>
# 542816            2  <rdkit.Chem.rdchem.Mol object at 0x1304f0c60>
# 542817            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0cb0>
# 542818            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0d00>
# 542819            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0d50>
# 542820            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0da0>
# 542821            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0e40>
# 542822            0  <rdkit.Chem.rdchem.Mol object at 0x1304f0e90>
# 542823            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0ee0>
# 542824            1  <rdkit.Chem.rdchem.Mol object at 0x1304f0f30>
# 542825            2  <rdkit.Chem.rdchem.Mol object at 0x1304f0f80>
#
#         agrochemical
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# 5                  4
# 6                  4
# 7                  4
# 8                  4
# 9                  4
# 10                 4
# 11                 4
# 12                 4
# 13                 4
# 14                 4
# 15                 4
# 16                 4
# 17                 4
# 18                 4
# 19                 4
# 20                 4
# 21                 4
# 22                 4
# 23                 4
# 24                 4
# 25                 4
# 26                 4
# 27                 4
# 28                 4
# 29                 4
# ...              ...
# 542796             1
# 542797             1
# 542798             1
# 542799             1
# 542800             1
# 542801             1
# 542802             1
# 542803             1
# 542804             1
# 542805             1
# 542806             1
# 542807             1
# 542808             1
# 542809             1
# 542810             1
# 542811             1
# 542812             1
# 542813             1
# 542814             1
# 542815             1
# 542816             1
# 542817             1
# 542818             1
# 542819             1
# 542820             1
# 542821             1
# 542822             1
# 542823             1
# 542824             1
# 542825             1
#
# [542826 rows x 19 columns]

# %% [markdown]
# ### Save data as pickle file labeled dataset2 (all data)

# %%
data.to_pickle("./multiclass_classification/data/dataset2.pkl")

# %% [markdown]
# ### Save another dataset: dataset1 (balanced dataset with approximately equal proportion of agro and non-agrochemicals)

# %%
agrochemicals = data.loc[data['agrochemical'] != 4]
nonagrochemicals = data.loc[data['agrochemical'] == 4]

# %%
nonagrochemicals = shuffle(nonagrochemicals)
nonagrochemicals = nonagrochemicals[:15000]

# %%
dataset1 = pd.concat([agrochemicals, nonagrochemicals], axis=0)

# %%
dataset1
# Out:
#                                                    smiles    category  \
# 529239                     CC(C)c1ccnc(c1)c2cc(ccn2)C(C)C  fungicidal
# 529240                    COc1ccccc1c2ccnc(c2)c3cc(C)ccn3  fungicidal
# 529241                      Cc1ccnc(c1)c2cc(ccn2)c3ccccc3  fungicidal
# 529242                       COc1ccccc1c2ccnc(c2)c3ccccn3  fungicidal
# 529243             [O-][N+](=O)c1ccccc1c2ccnc(c2)c3ccccn3  fungicidal
# 529244                       c1ccc(cc1)c2ccnc(c2)c3ccccn3  fungicidal
# 529245                      Cc1ccnc(c1)c2ccc(cn2)c3ccccc3  fungicidal
# 529246           [O-][N+](=O)c1ccc(cc1)c2ccc(nc2)c3ccccn3  fungicidal
# 529247                     COc1ccc(cc1)c2ccc(nc2)c3ccccn3  fungicidal
# 529248                      Cc1ccc(cc1)c2ccc(nc2)c3ccccn3  fungicidal
# 529249                     Brc1ccc(cc1)c2ccc(nc2)c3ccccn3  fungicidal
# 529250                     Clc1ccc(cc1)c2ccc(nc2)c3ccccn3  fungicidal
# 
# 529252              2          13         0.66         170.084            2
# 529253              3          20         0.72         262.111            3
# 529254              3          19         0.69         250.091            2
# 529255              3          18         0.67           232.1            2
# 529256              2          22         0.56         296.225            2
# 529257              2          20         0.72         268.194            2
# 529258              2          13         0.69         227.958            2
# 529259              2          15         0.78         257.969            3
# 529260              2          15         0.78         257.969            3
# 529261              2          17         0.63         285.964            4
# 529262              2          15         0.73         252.953            3
# 529263              2          17         0.82         287.979            4
# 529264              2          21         0.63         345.985            6
# 529265              2          13         0.63         188.004            3
# 529266              2          17         0.77         232.048            6
# 529267              2          14         0.66         205.988            4
# 529268              2          13          0.6         172.027            4
# ...               ...         ...          ...             ...          ...
# 461130              3          21          0.8         302.072            5
# 477196              2          45         0.24         625.336           11
# 206                 0          34         0.45         472.355            4
# 5168                4          59          0.1         808.427           15
# 106216              3          30         0.65          422.13            6
# 508569              1          16         0.67         220.183            1
# 318069              4          31         0.43         436.132            9
# 376199              3          19         0.73         250.111            3
# 344551              3          27         0.36         382.135            5
# 227582              3          30         0.66         402.194            5
# 397018              2          20         0.92         290.082            4
# 263155              2          33          0.6         452.242            8
# 373967              0          29          0.6         404.236            4
# 442291              0          25         0.58         346.214            4
# 9475                2          20         0.78         292.052            6
# 285558              2          27         0.72         392.188            7
# 16702               1          15         0.65         244.007            4
# 78376               2          32         0.36         434.184            7
# 302096              4          23         0.62         322.052            6
# 331005              4          28         0.38          389.12            5
# 36080               2          17         0.81         228.101            5
# 499712              2          47         0.35         691.306           10
# 241141              4          31         0.25         471.038            7
# 435690              4          39         0.27         545.162            9
# 14832               2          20         0.81         267.089            4
# 46303               3          31         0.14         421.096            7
# 64487               1          27         0.67         381.238            9
# 489986              4          43         0.28         578.289            8
# 283662              2          21         0.64         285.064            6
# 390784              1          16         0.77         224.105            4
#
#        hbd_lipinski                                            mol  \
# 529239            0  <rdkit.Chem.rdchem.Mol object at 0x1303d89e0>
# 529240            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8a30>
# 529241            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8a80>
# 529242            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8ad0>
# 529243            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8b20>
# 529244            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8b70>
# 529245            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8bc0>
# 529246            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8c10>
# 529247            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8c60>
# 529248            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8cb0>
# 529249            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8d00>
# 529250            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8d50>
# 529251            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8da0>
# 529252            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8df0>
# 529253            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8e40>
# 529254            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8e90>
# 529255            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8ee0>
# 529256            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8f30>
# 529257            0  <rdkit.Chem.rdchem.Mol object at 0x1303d8f80>
# 529258            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9030>
# 529259            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9080>
# 529260            0  <rdkit.Chem.rdchem.Mol object at 0x1303d90d0>
# 529261            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9120>
# 529262            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9170>
# 529263            0  <rdkit.Chem.rdchem.Mol object at 0x1303d91c0>
# 529264            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9210>
# 529265            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9260>
# 529266            0  <rdkit.Chem.rdchem.Mol object at 0x1303d92b0>
# 529267            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9300>
# 529268            0  <rdkit.Chem.rdchem.Mol object at 0x1303d9350>
# ...             ...                                            ...
# 461130            1  <rdkit.Chem.rdchem.Mol object at 0x12fe66f30>
# 477196            2  <rdkit.Chem.rdchem.Mol object at 0x12ffb9620>
# 206               3  <rdkit.Chem.rdchem.Mol object at 0x1a7d1ee90>
# 5168              9  <rdkit.Chem.rdchem.Mol object at 0x10f9708a0>
# 106216            1  <rdkit.Chem.rdchem.Mol object at 0x12e27d530>
# 508569            1  <rdkit.Chem.rdchem.Mol object at 0x130230b70>
# 318069            1  <rdkit.Chem.rdchem.Mol object at 0x12f319c60>
# 376199            2  <rdkit.Chem.rdchem.Mol object at 0x12f7a9e40>
# 344551            1  <rdkit.Chem.rdchem.Mol object at 0x12f52f170>
# 227582            1  <rdkit.Chem.rdchem.Mol object at 0x12ec03c60>
# 397018            1  <rdkit.Chem.rdchem.Mol object at 0x12f94d4e0>
# 263155            3  <rdkit.Chem.rdchem.Mol object at 0x12eecbbc0>
# 373967            0  <rdkit.Chem.rdchem.Mol object at 0x12f77d0d0>
# 442291            1  <rdkit.Chem.rdchem.Mol object at 0x12fce0210>
# 9475              0  <rdkit.Chem.rdchem.Mol object at 0x110367580>
# 285558            3  <rdkit.Chem.rdchem.Mol object at 0x12f08e1c0>
# 16702             1  <rdkit.Chem.rdchem.Mol object at 0x111c273a0>
# 78376             0  <rdkit.Chem.rdchem.Mol object at 0x12e04ef30>
# 302096            1  <rdkit.Chem.rdchem.Mol object at 0x12f1d98f0>
# 331005            0  <rdkit.Chem.rdchem.Mol object at 0x12f41f580>
# 36080             1  <rdkit.Chem.rdchem.Mol object at 0x11e83ae40>
# 499712            2  <rdkit.Chem.rdchem.Mol object at 0x13017d6c0>
# 241141            1  <rdkit.Chem.rdchem.Mol object at 0x12ed13350>
# 435690            3  <rdkit.Chem.rdchem.Mol object at 0x12fc56c10>
# 14832             1  <rdkit.Chem.rdchem.Mol object at 0x111c01b70>
# 46303             0  <rdkit.Chem.rdchem.Mol object at 0x11e908760>
# 64487             3  <rdkit.Chem.rdchem.Mol object at 0x11ea74a30>
# 489986            2  <rdkit.Chem.rdchem.Mol object at 0x1300ba260>
# 283662            0  <rdkit.Chem.rdchem.Mol object at 0x12f068300>
# 390784            2  <rdkit.Chem.rdchem.Mol object at 0x12f8d0580>
#
#         agrochemical
# 529239             3
# 529240             3
# 529241             3
# 529242             3
# 529243             3
# 529244             3
# 529245             3
# 529246             3
# 529247             3
# 529248             3
# 529249             3
# 529250             3
# 529251             3
# 529252             3
# 529253             3
# 529254             3
# 529255             3
# 529256             3
# 529257             3
# 529258             3
# 529259             3
# 529260             3
# 529261             3
# 529262             3
# 529263             3
# 529264             3
# 529265             3
# 529266             3
# 529267             3
# 529268             3
# ...              ...
# 461130             4
# 477196             4
# 206                4
# 5168               4
# 106216             4
# 508569             4
# 318069             4
# 376199             4
# 344551             4
# 227582             4
# 397018             4
# 263155             4
# 373967             4
# 442291             4
# 9475               4
# 285558             4
# 16702              4
# 78376              4
# 302096             4
# 331005             4
# 36080              4
# 499712             4
# 241141             4
# 435690             4
# 14832              4
# 46303              4
# 64487              4
# 489986             4
# 283662             4
# 390784             4
#
# [28587 rows x 19 columns]

# %%
dataset1.to_pickle("./multiclass_classification/data/dataset1.pkl")
