# %% [markdown]
# Data is extracted from chembl_24.db (from [ChEMBL database](https://www.ebi.ac.uk/chembl/downloads)). We then parse the data and save data into pickle file for use in deep learning of the structures.

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import os
import sqlite3
import pickle
import rdkit.Chem as chem

from sklearn.utils import shuffle

# %% [markdown]
# Connect database using sqlite3 package

# %%
db = sqlite3.connect('../chembl_24.db')
c = db.cursor()

# %% [markdown]
# Import doc_id from chembl_24.db, then use doc_id to extract molregno (unique internal Chembl compound identifier)

# %%
categories = ['%toxin%', '%fungicidal%', '%nematicidal%', '%herbicidal%', '%insecticidal%']

# %%
molregno = dict.fromkeys(categories, None)
for cat in categories:
    # extract doc_id from assays that contain agrochemical and non-agrochemical keywords
    doc_id = c.execute("SELECT doc_id FROM assays where description like '%s'" %cat).fetchall()
    doc_id = [i[0] for i in doc_id]
    
    # extract unique compound identifier from doc_id
    molregno[cat] = c.execute("SELECT molregno FROM compound_records WHERE doc_id IN " + str(tuple(doc_id))).fetchall()
    molregno[cat] = set([i[0] for i in molregno[cat]])
    
    print ("%s" %cat[1:-1], ":", len(molregno[cat]))
# Out:
# toxin : 496979
# fungicidal : 4279
# nematicidal : 497
# herbicidal : 3454
# insecticidal : 5201

# %% [markdown]
# Dispose of toxin data that overlaps with any agrochemical type

# %%
# %%time
for agro in categories[1:]:
    intersection = molregno["%toxin%"] & molregno[agro]
    print ("Common to toxins and %ses:" %agro[1:-3], len(intersection))
    molregno["%toxin%"] = molregno["%toxin%"].difference(intersection)
    molregno[agro] = molregno[agro].difference(intersection)
# Out:
# Common to toxins and fungicides: 285
# Common to toxins and nematicides: 141
# Common to toxins and herbicides: 128
# Common to toxins and insecticides: 410
# CPU times: user 91.8 ms, sys: 19.6 ms, total: 111 ms
# Wall time: 109 ms

# %% [markdown]
# Group all agrochemicals into one class and remove duplicates

# %%
molregno['agrochemical'] = molregno[categories[1]] | molregno[categories[2]] | molregno[categories[3]] | molregno[categories[4]]

# %%
categories = ['%toxin%', 'agrochemical']
for cat in categories:
    molregno[cat] = list(molregno[cat])
    print ("%s" %cat[1:-1], ":", len(molregno[cat]))
# Out:
# toxin : 496015
# grochemica : 11996

# %% [markdown]
# Then, we get canonical smiles string and compound properties from molregno compound identifier. We check to make sure the smiles strings and properties are mapped exactly.
#
# - mw_freebase = Molecular weight of parent compound
# - alogp = Calculated ALogP
# - hba = number of hydrogen bond acceptors
# - hbd = number of hydrogen bond donors
# - psa = polar surface area
# - rtb = number of rotatable bonds
# - acd_logp = calculated octanol/water partition coefficient using ACDlabs v12.01
# - acd_logd = calculated octanol/water distribution coefficient at pH 7.4 using ACDlabs v12.01
# - full_mwt = molecular weight of the full compound including any salts
# - aromatic_rings = number of aromatic rings
# - heavy_atoms = number of heavy (non-hydrogen) atoms
# - qed_weighted = weighted quantitative estimate of drug likeness
# - mw_monoisotopic = monoisotopic parent molecular weight
# - hba_lipinski = number of hydrogen bond acceptros calculated according to the Lipinski's original rules (i.e. N + O count)
# - hbd_lipinski = number of hydrogen bond donors calculated according to the Lipinski's original rules (i.e., NH + OH count)

# %%
smiles_string = dict.fromkeys(categories, None)
mw_freebase_dict = dict.fromkeys(categories, None)
alogp_dict = dict.fromkeys(categories, None)
hba_dict = dict.fromkeys(categories, None)
hbd_dict = dict.fromkeys(categories, None)
psa_dict = dict.fromkeys(categories, None)
rtb_dict = dict.fromkeys(categories, None)
acd_logp_dict = dict.fromkeys(categories, None)
acd_logd_dict = dict.fromkeys(categories, None)
full_mwt_dict = dict.fromkeys(categories, None)
aromatic_rings_dict = dict.fromkeys(categories, None)
heavy_atoms_dict = dict.fromkeys(categories, None)
qed_weighted_dict = dict.fromkeys(categories, None)
mw_monoisotopic_dict = dict.fromkeys(categories, None)
hba_lipinski_dict = dict.fromkeys(categories, None)
hbd_lipinski_dict = dict.fromkeys(categories, None)

# %%
for cat in categories:
    smiles_string[cat], mw_freebase_dict[cat], alogp_dict[cat], hba_dict[cat], hbd_dict[cat], psa_dict[cat] = [], [], [], [], [], []
    rtb_dict[cat], acd_logp_dict[cat], acd_logd_dict[cat], full_mwt_dict[cat], aromatic_rings_dict[cat], heavy_atoms_dict[cat] = [], [], [], [], [], []
    qed_weighted_dict[cat], mw_monoisotopic_dict[cat], hba_lipinski_dict[cat], hbd_lipinski_dict[cat] = [], [], [], []
    for num in molregno[cat]:
        smile = c.execute("SELECT canonical_smiles FROM compound_structures WHERE molregno = " + str(num)).fetchall()
        properties = c.execute("SELECT * FROM compound_properties WHERE molregno = " + str(num)).fetchall()
        if not smile or not properties:
            molregno[cat].remove(num)
        else:
            properties = properties[0]
            smiles_string[cat].append(smile[0])
            
            # assign properties to corresponding dictionaries
            mw_freebase_dict[cat].append(properties[1])
            alogp_dict[cat].append(properties[2])
            hba_dict[cat].append(properties[3])
            hbd_dict[cat].append(properties[4])
            psa_dict[cat].append(properties[5])
            rtb_dict[cat].append(properties[6])
            acd_logp_dict[cat].append(properties[11])
            acd_logd_dict[cat].append(properties[12])
            full_mwt_dict[cat].append(properties[14])
            aromatic_rings_dict[cat].append(properties[15])
            heavy_atoms_dict[cat].append(properties[16])
            qed_weighted_dict[cat].append(properties[17])
            mw_monoisotopic_dict[cat].append(properties[18])
            hba_lipinski_dict[cat].append(properties[20])
            hbd_lipinski_dict[cat].append(properties[21])

# %% [markdown]
# Convert smiles string and the properties into a long list and then create another list containing their corresponding categorical name

# %%
canonical_smiles, label = [], []
mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],
for i, cat in enumerate(smiles_string):
    canonical_smiles += smiles_string[cat]
    label += [i]*len(smiles_string[cat])
    
    mw_freebase += mw_freebase_dict[cat]
    alogp += alogp_dict[cat]
    hba += hba_dict[cat]
    hbd += hbd_dict[cat]
    psa += psa_dict[cat]
    rtb += rtb_dict[cat]
    acd_logp += acd_logp_dict[cat]
    acd_logd += acd_logd_dict[cat]
    full_mwt += full_mwt_dict[cat]
    aromatic_rings += aromatic_rings_dict[cat]
    heavy_atoms += heavy_atoms_dict[cat]
    qed_weighted += qed_weighted_dict[cat]
    mw_monoisotopic += mw_monoisotopic_dict[cat]
    hba_lipinski += hba_lipinski_dict[cat]
    hbd_lipinski += hbd_lipinski_dict[cat]

# %% [markdown]
# Stack the two lists together

# %%
data = np.column_stack((canonical_smiles, label, mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski))

# %% [markdown]
# Convert data into pandas dataframe

# %%
data = pd.DataFrame(data, columns=['smiles', 'agrochemical', 'mw_freebase', 'alogp', 'hba', 'hbd', 'psa', 'rtb', 'acd_logp', 'acd_logd', 'full_mwt', 'aromatic_rings', 'heavy_atoms', 'qed_weighted', 'mw_monoisotopic', 'hba_lipinski', 'hbd_lipinski'])

# %% [markdown]
# Add a column containing RDKit Molecule class

# %%
# %%time
data['mol'] = data['smiles'].apply(chem.MolFromSmiles)
# Out:
# CPU times: user 2min 55s, sys: 5.52 s, total: 3min
# Wall time: 3min 2s

# %% [markdown]
# Remove null values

# %%
data.dropna(axis=0, inplace=True)

# %% [markdown]
# Reset index

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Count number of compounds in agrochemical and non-agrochemical category

# %%
data['agrochemical'].value_counts()
# Out:
# 0    487474
# 1     11543
# Name: agrochemical, dtype: int64

# %%
data
# Out:
#                                                    smiles agrochemical  \
# 0                     Br\C=C\1/CCC(C(=O)O1)c2cccc3ccccc23            0
# 1       Oc1ccc(cc1NC(=O)c2ccccc2NS(=O)(=O)c3ccc(F)cc3)...            0
# 2          [Na+].Cc1cc(CC(=O)[O-])n(C)c1C(=O)c2ccc(Cl)cc2            0
# 3                        CCN1C=C(C(=O)O)C(=O)c2ccc(C)nc12            0
# 4              Oc1cc2C(=O)Oc3c(O)c(O)cc4C(=O)Oc(c1O)c2c34            0
# 5             CC1(C)[C@@H](N2[C@@H](CC2=O)S1(=O)=O)C(=O)O            0
# 6       CN1CCN(CC1)c2cc3N(C=C(C(=O)O)C(=O)c3cc2F)c4ccc...            0
# 7       C[C@]1(Cn2ccnn2)[C@@H](N3[C@@H](CC3=O)S1(=O)=O...            0
# 8         CN1CCN(CC1)c2c(F)cc3C(=O)C(=CN(CCF)c3c2F)C(=O)O            0
# 9       Cn1cc(C2=C(C(=O)NC2=O)c3cn(CCCSC(=N)N)c4ccccc3...            0
# 10                                     CCc1cc2c(O)ncnc2s1            0
# 11      C[S+]([O-])c1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)...            0
# 12                  C1Cc2nc(c3ccccn3)c(c4ccc5OCOc5c4)n2C1            0
# 13                      Fc1ccc(cc1)c2c(nc3SCCn23)c4ccncc4            0
# 14                      Cc1ccc(Sc2cncc3sc(cc23)C(=O)N)cc1            0
# 15      NC(=O)c1ccc(cc1)c2nc(c3ccccn3)c([nH]2)c4ccc5OC...            0
# 16        OCc1ccc(cc1)c2nc(c3ccccn3)c([nH]2)c4ccc5OCOc5c4            0
# 17      COc1ccc(cc1OC)C(=O)O[C@H]2CC[C@@]3(C)[C@H]4CC[...            0
# 18                 Clc1ccc(cc1Cl)C(=O)CN2CCSC2=NCc3ccccc3            0
# 19                       CCC(C(CC)c1ccc(O)cc1)c2ccc(O)cc2            0
# 20                               C1Cc2c(CN1)[nH]c3ccccc23            0
# 21                       CC1OC(C(O)C1O)N2C=C(F)C(=O)NC2=O            0
# 22                                 O=C1Nc2ccccc2C13OCCCO3            0
# 23                                COc1cc(CC(C)N)c(OC)cc1I            0
# 24                                    NCCc1c[nH]c2ccccc12            0
# 25                               COc1ccc2[nH]c3CNCCc3c2c1            0
# 26                               COc1ccc(CSC2=NCCN2)cc1Cl            0
# 27             CN(C)c1cccc2c(cccc12)S(=O)(=O)Nc3onc(C)c3C            0
# 28                         OCC1OC(CC1O)N2C=C(F)C(=O)NC2=O            0
# 29      [O-][N+](=O)O[C@H]1CO[C@@H]2[C@@H](CO[C@H]12)O...            0
# ...                                                   ...          ...
# 498987  Fc1ccc(cc1)c2cncc(c2)C3C4=C(COC4=O)Nc5cc6OCOc6...            1
# 498988    COc1c(Cl)cc(cc1Cl)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 498989         Fc1ccc(cc1Br)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 498990     COc1cc(cc(O)c1OC)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 498991    COc1cc(cc(SC)c1OC)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 498992  [O-][N+](=O)\N=C/1\N(CCN2CCN(Cc3ccc(Cl)nc3)/C/...            1
# 498993  COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4cc(OC)c(OC)c(...            1
# 498994     COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4cc(C)cc(C)c24            1
# 498995   COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4cc(OC)cc(OC)c24            1
# 498996     COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4c(C)c(C)ccc24            1
# 498997  Clc1cccc(c1)C2C3=C(Nc4cc5OCOc5cc24)C(=O)C(C3=O...            1
# 498998     COc1cc(cc2OCOc12)C3C4=C(COC4=O)Nc5cc6OCOc6cc35            1
# 498999       O=C1OCC2=C1C(c3cccc(OCC#N)c3)c4cc5OCOc5cc4N2            1
# 499000        COc1cc(ccc1Cl)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 499001         Fc1ccc(cc1Cl)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 499002          COc1ccc(cn1)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
# 499003  [O-][N+](=O)\N=C/1\N(CCCCN2CCN(Cc3ccc(Cl)nc3)/...            1
# 499004  [O-][N+](=O)\N=C/1\N(CCCCCCCCN2CCN(Cc3ccc(Cl)n...            1
# 499005  CC(C)(C)c1[nH]cnc1\C=C\2/NC(=O)\C(=C\c3cccc(F)...            1
# 499006     COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4c(C)cc(C)cc24            1
# 499007    COc1cc(OC)cc(c1)C2C3=C(COC3=O)Nc4c(OC)cc(C)cc24            1
# 499008  COc1cc(cc(OC)c1OC)C2(C)C3=C(COC3=O)Nc4cc(Cl)ccc24            1
# 499009        CC1(C2=C(COC2=O)Nc3ccc(Cl)cc13)c4cccc(Cl)c4            1
# 499010  COc1cc(cc(OC)c1OC)C2(C)C3=C(COC3=O)N(C)c4cc5OC...            1
# 499011     Brc1cc(cc2OCOc12)C3C4=C(COC4=O)Nc5cc6OCOc6cc35            1
# 499012         COc1cc(ccc1F)C2C3=C(COC3=O)Nc4cc5OCOc5cc24            1
#
# 498991              2          29          0.6         413.093            7
# 498992              2          36         0.26          536.12           14
# 498993              2          30         0.72         413.147            8
# 498994              2          26         0.85         351.147            5
# 498995              2          28          0.8         383.137            7
# 498996              2          26         0.85         351.147            5
# 498997              3          31         0.59         429.077            5
# 498998              2          28         0.79         381.085            8
# 498999              2          27         0.84          362.09            7
# 499000              2          26         0.82         371.056            6
# 499001              2          25         0.79         359.036            5
# 499002              2          25         0.84          338.09            7
# 499003              2          38         0.17         564.152           14
# 499004              2          42         0.12         620.214           14
# 499005              3          26         0.64         354.149            6
# 499006              2          26         0.85         351.147            5
# 499007              2          27         0.84         367.142            6
# 499008              2          28         0.78         401.103            6
# 499009              2          23         0.77         345.032            3
# 499010              2          31         0.69         425.147            8
# 499011              2          27          0.7         428.985            7
# 499012              2          26         0.84         355.086            6
# 499013              2          26         0.62         361.056            5
# 499014              2          30         0.59         423.073            6
# 499015              2          27          0.8         367.106            7
# 499016              2          25         0.74         340.131            5
#
#        hbd_lipinski                                            mol
# 0                 0  <rdkit.Chem.rdchem.Mol object at 0x1059d9a30>
# 1                 3  <rdkit.Chem.rdchem.Mol object at 0x12899f620>
# 2                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f530>
# 3                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f6c0>
# 4                 4  <rdkit.Chem.rdchem.Mol object at 0x12899f5d0>
# 5                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f760>
# 6                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f670>
# 7                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f800>
# 8                 1  <rdkit.Chem.rdchem.Mol object at 0x12899f710>
# 9                 4  <rdkit.Chem.rdchem.Mol object at 0x12899f8a0>
# 10                1  <rdkit.Chem.rdchem.Mol object at 0x12899f7b0>
# 11                1  <rdkit.Chem.rdchem.Mol object at 0x12899f940>
# 12                0  <rdkit.Chem.rdchem.Mol object at 0x12899f850>
# 13                0  <rdkit.Chem.rdchem.Mol object at 0x12899f9e0>
# 14                2  <rdkit.Chem.rdchem.Mol object at 0x12899f8f0>
# 15                3  <rdkit.Chem.rdchem.Mol object at 0x12899fad0>
# 16                2  <rdkit.Chem.rdchem.Mol object at 0x12899fb70>
# 17                6  <rdkit.Chem.rdchem.Mol object at 0x12899fb20>
# 18                0  <rdkit.Chem.rdchem.Mol object at 0x197924e40>
# 19                2  <rdkit.Chem.rdchem.Mol object at 0x197924ee0>
# 20                2  <rdkit.Chem.rdchem.Mol object at 0x197924f30>
# 21                3  <rdkit.Chem.rdchem.Mol object at 0x197924f80>
# 22                1  <rdkit.Chem.rdchem.Mol object at 0x199c61030>
# 23                2  <rdkit.Chem.rdchem.Mol object at 0x199c61080>
# 24                3  <rdkit.Chem.rdchem.Mol object at 0x199c610d0>
# 25                2  <rdkit.Chem.rdchem.Mol object at 0x199c61120>
# 26                1  <rdkit.Chem.rdchem.Mol object at 0x199c61170>
# 27                1  <rdkit.Chem.rdchem.Mol object at 0x199c611c0>
# 28                3  <rdkit.Chem.rdchem.Mol object at 0x199c61210>
# 29                0  <rdkit.Chem.rdchem.Mol object at 0x199c61260>
# ...             ...                                            ...
# 498987            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d3a0>
# 498988            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d3f0>
# 498989            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d440>
# 498990            2  <rdkit.Chem.rdchem.Mol object at 0x12ec4d490>
# 498991            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d4e0>
# 498992            0  <rdkit.Chem.rdchem.Mol object at 0x12ec4d530>
# 498993            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d580>
# 498994            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d5d0>
# 498995            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d620>
# 498996            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d670>
# 498997            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d6c0>
# 498998            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d710>
# 498999            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d760>
# 499000            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d7b0>
# 499001            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d800>
# 499002            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d850>
# 499003            0  <rdkit.Chem.rdchem.Mol object at 0x12ec4d8a0>
# 499004            0  <rdkit.Chem.rdchem.Mol object at 0x12ec4d8f0>
# 499005            3  <rdkit.Chem.rdchem.Mol object at 0x12ec4d940>
# 499006            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d990>
# 499007            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4d9e0>
# 499008            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4da30>
# 499009            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4da80>
# 499010            0  <rdkit.Chem.rdchem.Mol object at 0x12ec4dad0>
# 499011            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4db20>
# 499012            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4db70>
# 499013            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4dbc0>
# 499014            1  <rdkit.Chem.rdchem.Mol object at 0x12ec4dc10>
# 499015            2  <rdkit.Chem.rdchem.Mol object at 0x12ec4dc60>
# 499016            0  <rdkit.Chem.rdchem.Mol object at 0x12ec4dcb0>
#
# [499017 rows x 18 columns]

# %% [markdown]
# ### Save data as pickle file labeled dataset2 (all data)

# %%
data.to_pickle("./binary_classification/data/dataset2.pkl")

# %% [markdown]
# ### Save another dataset: dataset1 (balanced dataset with approximately equal proportion of agro and non-agrochemicals)

# %%
agrochemicals = data.loc[data['agrochemical'] == 1]
nonagrochemicals = data.loc[data['agrochemical'] == 0]

# %%
type(agrochemicals)
# Out:
# pandas.core.frame.DataFrame

# %%
nonagrochemicals = shuffle(nonagrochemicals)
nonagrochemicals = nonagrochemicals[:15000]

# %%
dataset1 = pd.concat([agrochemicals, nonagrochemicals], axis=0)

# %%
dataset1
# Out:
#                                                    smiles agrochemical  \
# 487474  COc1cc2N(C)C3=C(C(=O)OC3)C(C)(c4cc(OC)c(OC)c(O...            1
# 487475    CN1C2=C(C(=O)OC2)C(C)(c3ccc(Cl)cc3)c4ccc(C)cc14            1
# 487476  CCN1C2=C(C(=O)OC2)C(C)(c3cc(OC)cc(OC)c3)c4cc5O...            1
# 487477  CCN1C2=C(C(=O)OC2)C(C)(c3cc(OC)cc(OC)c3)c4cc(O...            1
# 487478  COc1ccc2c(c1)N(C)C3=C(C(=O)OC3)C2(C)c4cc(OC)cc...            1
# 487479      Clc1cc(Cl)cc(c1)C2C3=C(COC3=O)Oc4cc5OCOc5cc24            1
# 487480          Clc1cccc(c1)C2C3=C(COC3=O)Oc4cc5OCOc5cc24            1
# 487481                      NC(=N)Nc1ccccc1SCc2ccc(Cl)cc2            1
# 487482      Clc1ccc(CSc2ccccc2N=C(NC3CCCCC3)NC4CCCCC4)cc1            1
# 487483                            Nc1ccccc1SCc2ccc(Cl)cc2            1
# 487474              2          32         0.63         441.179            8
# 487475              2          24         0.73         339.103            3
# 487476              2          30         0.72         409.152            7
# 487477              2          31         0.65         425.184            7
# 487478              2          28         0.76         381.158            6
# 487479              2          25          0.7          375.99            5
# 487480              2          24         0.74         342.029            5
# 487481              2          19         0.45          291.06            3
# 487482              2          31         0.27         455.216            3
# 487483              2          16         0.65         249.038            1
# 487484              1          17         0.51         235.157            3
# 487485              1          15         0.53         207.126            3
# 487486              2          19         0.45          291.06            3
# 487487              2          31         0.27         455.216            3
# 487488              2          22         0.34         333.082            5
# 487489              2          19         0.45          291.06            3
# 487490              2          31         0.27         455.216            3
# 487491              2          22         0.34         333.082            5
# 487492              2          16         0.65         249.038            1
# 487493              2          20         0.38          412.92            3
# 487494              2          32         0.21         577.076            3
# 487495              2          17          0.6         370.898            1
# 487496              2          20         0.38          412.92            3
# 487497              2          32         0.21         577.076            3
# 487498              2          23         0.27         454.942            5
# 487499              2          20         0.38          412.92            3
# 487500              2          32         0.21         577.076            3
# 487501              2          23         0.27         454.942            5
# 487502              2          17          0.6         370.898            1
# 487503              2          22         0.66         359.974            6
# ...               ...         ...          ...             ...          ...
# 66028               2          29         0.74         391.153            7
# 319731              3          29         0.51         411.114            6
# 448893              0          18         0.59         280.065            4
# 440529              3          22         0.71         295.168            4
# 215126              2          24         0.92         322.204            3
# 467046              4          29         0.55         403.109            5
# 224130              0          19         0.77         287.094            7
# 154503              2          37         0.32         514.243           11
# 232517              2          22         0.95         301.123            5
# 302337              2          38         0.41         546.215           11
# 477802              0          10         0.53         158.015            4
# 369787              3          26         0.68         370.085            9
# 462706              3          40         0.46         542.242            8
# 461486              1          17         0.77         255.093            4
# 74002               2          25         0.59         334.123            5
# 45443               3          18         0.56          244.06            7
# 412645              3          30         0.64         430.141            8
# 101823              4          53         0.09         723.268           12
# 99673               4          24         0.34         323.102            8
# 137408              1          22         0.86         302.163            5
# 273470              3          23         0.52         302.154            2
# 270583              1          19         0.87          288.05            4
# 125904              1          12          0.7         186.046            4
# 399058              4          28         0.54         390.115            6
# 129477              2          23         0.87         336.104            4
# 225528              2          21          0.6         284.105            4
# 353019              3          29         0.69         413.152            8
# 319866              4          27         0.59         363.122            7
# 108921              3          44         0.31         634.119           12
# 283852              1          23         0.81         336.058            6
#
#        hbd_lipinski                                            mol
# 487474            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f030>
# 487475            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f080>
# 487476            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f0d0>
# 487477            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f120>
# 487478            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f170>
# 487479            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f1c0>
# 487480            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f210>
# 487481            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f260>
# 487482            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f2b0>
# 487483            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f300>
# 487484            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f350>
# 487485            0  <rdkit.Chem.rdchem.Mol object at 0x12eb5f3a0>
# 487486            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f3f0>
# 487487            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f440>
# 487488            6  <rdkit.Chem.rdchem.Mol object at 0x12eb5f490>
# 487489            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f4e0>
# 487490            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f530>
# 487491            6  <rdkit.Chem.rdchem.Mol object at 0x12eb5f580>
# 487492            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f5d0>
# 487493            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f620>
# 487494            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f670>
# 487495            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f6c0>
# 487496            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f710>
# 487497            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f760>
# 487498            6  <rdkit.Chem.rdchem.Mol object at 0x12eb5f7b0>
# 487499            4  <rdkit.Chem.rdchem.Mol object at 0x12eb5f800>
# 487500            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f850>
# 487501            6  <rdkit.Chem.rdchem.Mol object at 0x12eb5f8a0>
# 487502            2  <rdkit.Chem.rdchem.Mol object at 0x12eb5f8f0>
# 487503            1  <rdkit.Chem.rdchem.Mol object at 0x12eb5f940>
# ...             ...                                            ...
# 66028             2  <rdkit.Chem.rdchem.Mol object at 0x11ec44350>
# 319731            2  <rdkit.Chem.rdchem.Mol object at 0x12de38bc0>
# 448893            2  <rdkit.Chem.rdchem.Mol object at 0x12e858620>
# 440529            0  <rdkit.Chem.rdchem.Mol object at 0x12e7b0a30>
# 215126            1  <rdkit.Chem.rdchem.Mol object at 0x12d603e90>
# 467046            1  <rdkit.Chem.rdchem.Mol object at 0x12e9c4d50>
# 224130            1  <rdkit.Chem.rdchem.Mol object at 0x12d6b9580>
# 154503            5  <rdkit.Chem.rdchem.Mol object at 0x12d137120>
# 232517            1  <rdkit.Chem.rdchem.Mol object at 0x12d7618f0>
# 302337            3  <rdkit.Chem.rdchem.Mol object at 0x12dcdb120>
# 477802            1  <rdkit.Chem.rdchem.Mol object at 0x12ea9cda0>
# 369787            1  <rdkit.Chem.rdchem.Mol object at 0x12e2254e0>
# 462706            1  <rdkit.Chem.rdchem.Mol object at 0x12e96d990>
# 461486            0  <rdkit.Chem.rdchem.Mol object at 0x12e9551c0>
# 74002             3  <rdkit.Chem.rdchem.Mol object at 0x11ece4a30>
# 45443             3  <rdkit.Chem.rdchem.Mol object at 0x11eaa6bc0>
# 412645            1  <rdkit.Chem.rdchem.Mol object at 0x12e5813a0>
# 101823            4  <rdkit.Chem.rdchem.Mol object at 0x12ccff670>
# 99673             0  <rdkit.Chem.rdchem.Mol object at 0x12ccd2d50>
# 137408            2  <rdkit.Chem.rdchem.Mol object at 0x12cfdd7b0>
# 273470            0  <rdkit.Chem.rdchem.Mol object at 0x12da97f80>
# 270583            4  <rdkit.Chem.rdchem.Mol object at 0x12da5df30>
# 125904            3  <rdkit.Chem.rdchem.Mol object at 0x12cef3990>
# 399058            1  <rdkit.Chem.rdchem.Mol object at 0x12e4708f0>
# 129477            1  <rdkit.Chem.rdchem.Mol object at 0x12cf3da30>
# 225528            0  <rdkit.Chem.rdchem.Mol object at 0x12d6d55d0>
# 353019            1  <rdkit.Chem.rdchem.Mol object at 0x12e0d4da0>
# 319866            1  <rdkit.Chem.rdchem.Mol object at 0x12de3b710>
# 108921            0  <rdkit.Chem.rdchem.Mol object at 0x12cd92080>
# 283852            2  <rdkit.Chem.rdchem.Mol object at 0x12db68530>
#
# [26543 rows x 18 columns]

# %%
dataset1.to_pickle("./binary_classification/data/dataset1.pkl")
