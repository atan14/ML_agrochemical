# %% [markdown]
# Data is extracted from chembl_24.db (from [ChEMBL database](https://www.ebi.ac.uk/chembl/downloads)). We then parse the data and save data into pickle file for use in deep learning of the structures.

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import os
import sqlite3
import pickle
import rdkit.Chem as chem

from sklearn.utils import shuffle

# %% [markdown]
# Connect database using sqlite3 package

# %%
db = sqlite3.connect('../chembl_24.db')
c = db.cursor()

# %% [markdown]
# Import doc_id from chembl_24.db, then use doc_id to extract molregno (unique internal Chembl compound identifier)

# %%
categories = ['%toxin%', '%fungicidal%', '%nematicidal%', '%herbicidal%', '%insecticidal%']

# %%
molregno = dict.fromkeys(categories, None)
for cat in categories:
    # extract doc_id from assays that contain agrochemical and non-agrochemical keywords
    doc_id = c.execute("SELECT doc_id FROM assays where description like '%s'" %cat).fetchall()
    doc_id = [i[0] for i in doc_id]
    
    # extract unique compound identifier from doc_id
    molregno[cat] = c.execute("SELECT molregno FROM compound_records WHERE doc_id IN " + str(tuple(doc_id))).fetchall()
    molregno[cat] = set([i[0] for i in molregno[cat]])
    
    print ("%s" %cat[1:-1], ":", len(molregno[cat]))
# Out:
# toxin : 496979
# fungicidal : 4279
# nematicidal : 497
# herbicidal : 3454
# insecticidal : 5201

# %% [markdown]
# Dispose of toxin data that overlaps with any agrochemical type

# %%
# %%time
for agro in categories[1:]:
    intersection = molregno["%toxin%"] & molregno[agro]
    print ("Common to toxins and %ses:" %agro[1:-3], len(intersection))
    molregno["%toxin%"] = molregno["%toxin%"].difference(intersection)
    molregno[agro] = molregno[agro].difference(intersection)
# Out:
# Common to toxins and fungicides: 285
# Common to toxins and nematicides: 141
# Common to toxins and herbicides: 128
# Common to toxins and insecticides: 410
# CPU times: user 91.3 ms, sys: 19.7 ms, total: 111 ms
# Wall time: 107 ms

# %% [markdown]
# Store agrochemicals that have multiple sub-agrochemical classes into another class for processing later

# %%
# %%time
molregno["%overlapped%"] = set()
for i, cat_a in enumerate(categories[1:]):
    for j, cat_b in enumerate(categories[i+2:]):
            intersection = molregno[cat_a] & molregno[cat_b]
            molregno["%overlapped%"] = molregno["%overlapped%"].union(intersection)
            print ("Common to %ses and %ses:" %(cat_a[1:-3], cat_b[1:-3]), len(intersection))
print ()
print ("Total compounds with overlapped functionalities:", len(molregno['%overlapped%']))
print ()
# Out:
# Common to fungicides and nematicides: 6
# Common to fungicides and herbicides: 114
# Common to fungicides and insecticides: 224
# Common to nematicides and herbicides: 6
# Common to nematicides and insecticides: 60
# Common to herbicides and insecticides: 95
#
# Total compounds with overlapped functionalities: 438
#
# CPU times: user 2.75 ms, sys: 1.15 ms, total: 3.9 ms
# Wall time: 3.94 ms

# %% [markdown]
# Group all sub-agrochemical together into one huge agrochemical class to remove duplicates and remove the ones which are in overlapping list too

# %%
molregno['%agrochemical%'] = molregno[categories[1]] | molregno[categories[2]] | molregno[categories[3]] | molregno[categories[4]]

# %%
molregno['%agrochemical%'] = molregno['%agrochemical%'].difference(molregno['%overlapped%'])
print (len(molregno['%agrochemical%']))
# Out:
# 11558

# %%
for cat in molregno:
    molregno[cat] = list(molregno[cat])
    print ("%s:" %cat[1:-1], len(molregno[cat]))
# Out:
# toxin: 496015
# fungicidal: 3994
# nematicidal: 356
# herbicidal: 3326
# insecticidal: 4791
# overlapped: 438
# agrochemical: 11558

# %% [markdown]
# Then, we get canonical smiles string and compound properties from molregno compound identifier. We check to make sure the smiles strings and properties are mapped exactly. Corresponding class label (herbicide=0, insecticide=1, nematicide=2, fungicide=3, toxin=4) is added too.
#
# - mw_freebase = Molecular weight of parent compound
# - alogp = Calculated ALogP
# - hba = number of hydrogen bond acceptors
# - hbd = number of hydrogen bond donors
# - psa = polar surface area
# - rtb = number of rotatable bonds
# - acd_logp = calculated octanol/water partition coefficient using ACDlabs v12.01
# - acd_logd = calculated octanol/water distribution coefficient at pH 7.4 using ACDlabs v12.01
# - full_mwt = molecular weight of the full compound including any salts
# - aromatic_rings = number of aromatic rings
# - heavy_atoms = number of heavy (non-hydrogen) atoms
# - qed_weighted = weighted quantitative estimate of drug likeness
# - mw_monoisotopic = monoisotopic parent molecular weight
# - hba_lipinski = number of hydrogen bond acceptros calculated according to the Lipinski's original rules (i.e. N + O count)
# - hbd_lipinski = number of hydrogen bond donors calculated according to the Lipinski's original rules (i.e., NH + OH count)

# %%
categories = ['%toxin%', '%agrochemical%', '%overlapped%']

# %%
def agrochemical_class_label(n):
    n_label = []
    if n in molregno['%herbicidal%']:
        n_label.append(0)
    if n in molregno['%insecticidal%']:
        n_label.append(1)
    if n in molregno['%nematicidal%']:
        n_label.append(2)
    if n in molregno['%fungicidal%']:
        n_label.append(3)
    return n_label

# %%
smiles_string = dict.fromkeys(categories, None)
mw_freebase_dict = dict.fromkeys(categories, None)
alogp_dict = dict.fromkeys(categories, None)
hba_dict = dict.fromkeys(categories, None)
hbd_dict = dict.fromkeys(categories, None)
psa_dict = dict.fromkeys(categories, None)
rtb_dict = dict.fromkeys(categories, None)
acd_logp_dict = dict.fromkeys(categories, None)
acd_logd_dict = dict.fromkeys(categories, None)
full_mwt_dict = dict.fromkeys(categories, None)
aromatic_rings_dict = dict.fromkeys(categories, None)
heavy_atoms_dict = dict.fromkeys(categories, None)
qed_weighted_dict = dict.fromkeys(categories, None)
mw_monoisotopic_dict = dict.fromkeys(categories, None)
hba_lipinski_dict = dict.fromkeys(categories, None)
hbd_lipinski_dict = dict.fromkeys(categories, None)
label_dict = dict.fromkeys(categories, None)

# %%
for cat in categories:
    smiles_string[cat], mw_freebase_dict[cat], alogp_dict[cat], hba_dict[cat], hbd_dict[cat], psa_dict[cat] = [], [], [], [], [], []
    rtb_dict[cat], acd_logp_dict[cat], acd_logd_dict[cat], full_mwt_dict[cat], aromatic_rings_dict[cat], heavy_atoms_dict[cat] = [], [], [], [], [], []
    qed_weighted_dict[cat], mw_monoisotopic_dict[cat], hba_lipinski_dict[cat], hbd_lipinski_dict[cat] = [], [], [], []
    label_dict[cat] = []
    for num in molregno[cat]:
        smile = c.execute("SELECT canonical_smiles FROM compound_structures WHERE molregno = " + str(num)).fetchall()
        properties = c.execute("SELECT * FROM compound_properties WHERE molregno = " + str(num)).fetchall()
        if not smile or not properties:
            molregno[cat].remove(num)
        else:
            if cat == '%toxin%':
                label_dict[cat].append([4])
            else:
                label_dict[cat].append(agrochemical_class_label(num))
            
            properties = properties[0]
            smiles_string[cat].append(smile[0])
            
            # assign properties to corresponding dictionaries
            mw_freebase_dict[cat].append(properties[1])
            alogp_dict[cat].append(properties[2])
            hba_dict[cat].append(properties[3])
            hbd_dict[cat].append(properties[4])
            psa_dict[cat].append(properties[5])
            rtb_dict[cat].append(properties[6])
            acd_logp_dict[cat].append(properties[11])
            acd_logd_dict[cat].append(properties[12])
            full_mwt_dict[cat].append(properties[14])
            aromatic_rings_dict[cat].append(properties[15])
            heavy_atoms_dict[cat].append(properties[16])
            qed_weighted_dict[cat].append(properties[17])
            mw_monoisotopic_dict[cat].append(properties[18])
            hba_lipinski_dict[cat].append(properties[20])
            hbd_lipinski_dict[cat].append(properties[21])

# %% [markdown]
# Convert smiles string and the properties into a long list for stacking into a pandas dataframe

# %%
canonical_smiles, label = [], []
mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski = [],[],[],[],[],[],[],[],[],[],[],[],[],[],[],
for cat in smiles_string:
    canonical_smiles += smiles_string[cat]
    
    label += label_dict[cat]
    
    mw_freebase += mw_freebase_dict[cat]
    alogp += alogp_dict[cat]
    hba += hba_dict[cat]
    hbd += hbd_dict[cat]
    psa += psa_dict[cat]
    rtb += rtb_dict[cat]
    acd_logp += acd_logp_dict[cat]
    acd_logd += acd_logd_dict[cat]
    full_mwt += full_mwt_dict[cat]
    aromatic_rings += aromatic_rings_dict[cat]
    heavy_atoms += heavy_atoms_dict[cat]
    qed_weighted += qed_weighted_dict[cat]
    mw_monoisotopic += mw_monoisotopic_dict[cat]
    hba_lipinski += hba_lipinski_dict[cat]
    hbd_lipinski += hbd_lipinski_dict[cat]

# %%
for cat in smiles_string:
    print (cat, len(smiles_string[cat]))
# Out:
# %toxin% 491627
# %agrochemical% 11504
# %overlapped% 438

# %% [markdown]
# Stack the lists together

# %%
data = np.column_stack((canonical_smiles, label, mw_freebase, alogp, hba, hbd, psa, rtb, acd_logp, acd_logd, full_mwt, aromatic_rings, heavy_atoms, qed_weighted, mw_monoisotopic, hba_lipinski, hbd_lipinski))

# %% [markdown]
# Convert data into pandas dataframe

# %%
data = pd.DataFrame(data, columns=['smiles', 'agrochemical', 'mw_freebase', 'alogp', 'hba', 'hbd', 'psa', 'rtb', 'acd_logp', 'acd_logd', 'full_mwt', 'aromatic_rings', 'heavy_atoms', 'qed_weighted', 'mw_monoisotopic', 'hba_lipinski', 'hbd_lipinski'])

# %% [markdown]
# Add a column containing RDKit Molecule class

# %%
# %%time
data['mol'] = data['smiles'].apply(chem.MolFromSmiles)
# Out:
# CPU times: user 2min 50s, sys: 4.68 s, total: 2min 54s
# Wall time: 2min 55s

# %% [markdown]
# Remove null values

# %%
data.dropna(axis=0, inplace=True)

# %% [markdown]
# Reset index

# %%
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Count number of agrochemicals and non-agrochemicals

# %%
nonagrochemicals_idx = [idx for idx, val in enumerate(data['agrochemical']) if val == [4]]
agrochemicals_idx = [idx for idx, val in enumerate(data['agrochemical']) if val != [4]]

# %%
agrochemicals = data.loc[agrochemicals_idx]
nonagrochemicals = data.loc[nonagrochemicals_idx]
print ("Agrochemicals:", len(agrochemicals))
print ("Nonagrochemicals:", len(nonagrochemicals))
# Out:
# Agrochemicals: 11543
# Nonagrochemicals: 487474

# %%
data
# Out:
#                                                    smiles agrochemical  \
# 0                     Br\C=C\1/CCC(C(=O)O1)c2cccc3ccccc23          [4]
# 1       Oc1ccc(cc1NC(=O)c2ccccc2NS(=O)(=O)c3ccc(F)cc3)...          [4]
# 2          [Na+].Cc1cc(CC(=O)[O-])n(C)c1C(=O)c2ccc(Cl)cc2          [4]
# 3                        CCN1C=C(C(=O)O)C(=O)c2ccc(C)nc12          [4]
# 4              Oc1cc2C(=O)Oc3c(O)c(O)cc4C(=O)Oc(c1O)c2c34          [4]
# 5             CC1(C)[C@@H](N2[C@@H](CC2=O)S1(=O)=O)C(=O)O          [4]
# 6       CN1CCN(CC1)c2cc3N(C=C(C(=O)O)C(=O)c3cc2F)c4ccc...          [4]
# 7       C[C@]1(Cn2ccnn2)[C@@H](N3[C@@H](CC3=O)S1(=O)=O...          [4]
# 8         CN1CCN(CC1)c2c(F)cc3C(=O)C(=CN(CCF)c3c2F)C(=O)O          [4]
# 9       Cn1cc(C2=C(C(=O)NC2=O)c3cn(CCCSC(=N)N)c4ccccc3...          [4]
# 10                                     CCc1cc2c(O)ncnc2s1          [4]
# 11      C[S+]([O-])c1ccc(cc1)c2nc(c3ccc(F)cc3)c([nH]2)...          [4]
# 12                  C1Cc2nc(c3ccccn3)c(c4ccc5OCOc5c4)n2C1          [4]
# 13                      Fc1ccc(cc1)c2c(nc3SCCn23)c4ccncc4          [4]
# 14                      Cc1ccc(Sc2cncc3sc(cc23)C(=O)N)cc1          [4]
# 15      NC(=O)c1ccc(cc1)c2nc(c3ccccn3)c([nH]2)c4ccc5OC...          [4]
# 16        OCc1ccc(cc1)c2nc(c3ccccn3)c([nH]2)c4ccc5OCOc5c4          [4]
# 17      COc1ccc(cc1OC)C(=O)O[C@H]2CC[C@@]3(C)[C@H]4CC[...          [4]
# 18                 Clc1ccc(cc1Cl)C(=O)CN2CCSC2=NCc3ccccc3          [4]
# 19                       CCC(C(CC)c1ccc(O)cc1)c2ccc(O)cc2          [4]
# 20                               C1Cc2c(CN1)[nH]c3ccccc23          [4]
# 21                       CC1OC(C(O)C1O)N2C=C(F)C(=O)NC2=O          [4]
# 22                                 O=C1Nc2ccccc2C13OCCCO3          [4]
# 23                                COc1cc(CC(C)N)c(OC)cc1I          [4]
# 24                                    NCCc1c[nH]c2ccccc12          [4]
# 25                               COc1ccc2[nH]c3CNCCc3c2c1          [4]
# 26                               COc1ccc(CSC2=NCCN2)cc1Cl          [4]
# 27             CN(C)c1cccc2c(cccc12)S(=O)(=O)Nc3onc(C)c3C          [4]
# 28                         OCC1OC(CC1O)N2C=C(F)C(=O)NC2=O          [4]
# 29      [O-][N+](=O)O[C@H]1CO[C@@H]2[C@@H](CO[C@H]12)O...          [4]
# ...                                                   ...          ...
# 498987     CCC#CCOc1ccc(CCNC(=O)[C@H](C)NS(=O)(=O)C)cc1OC       [0, 3]
# 498988  FC(F)(F)C1=NN(CN2CCN(CN3N=C(N(\N=C\c4ccccc4)C3...       [0, 3]
# 498989  CCC[C@H](NS(=O)(=O)C)C(=O)NCCc1ccc(OCC#CCC)c(O...       [0, 3]
# 498990  CCC#CCOc1ccc(CCNC(=O)[C@@H](NS(=O)(=O)C)C(C)C)...       [0, 3]
# 498991  CCC#CCOc1ccc(CCNC(=O)[C@@H](NS(=O)(=O)C)[C@@H]...       [0, 3]
# 498992  CCC#CCOc1ccc(CCNC(=O)[C@H](CC(C)C)NS(=O)(=O)C)...       [0, 3]
# 498993  Fc1ccccc1\C=N\N2C(=S)N(CN3CCN(CN4N=C(N(\N=C\c5...       [0, 3]
# 498994  Fc1ccccc1\C=N\N2C(=S)N(CN3CCN(CC3)c4ncccn4)N=C...       [0, 3]
# 498995  COc1ccc(\C=N\N2C(=S)N(CN3CCN(CC3)c4ncccn4)N=C2...       [0, 3]
# 498996  Cc1ccnc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4)C3=S)C...       [0, 3]
# 498997  Cc1ccnc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4F)C3=S)...       [0, 3]
# 498998  COc1ccc(\C=N\N2C(=S)N(CN3CCN(CC3)c4nccc(C)n4)N...       [0, 3]
# 498999  Cc1ccnc(n1)N2CCN(CN3N=C(N(\N=C\c4ccc(C)c(C)c4)...       [0, 3]
# 499000  Cc1ccnc(n1)N2CCN(CN3N=C(N(\N=C\c4ccc(Cl)cc4)C3...       [0, 3]
# 499001  Cc1ccnc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4[N+](=O...       [0, 3]
# 499002  Cc1cc(C)nc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4)C3=...       [0, 3]
# 499003  Cc1cc(C)nc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4F)C3...       [0, 3]
# 499004  COc1ccc(\C=N\N2C(=S)N(CN3CCN(CC3)c4nc(C)cc(C)n...       [0, 3]
# 499005  Cc1cc(C)nc(n1)N2CCN(CN3N=C(N(\N=C\c4ccc(C)c(C)...       [0, 3]
# 499006  Cc1cc(C)nc(n1)N2CCN(CN3N=C(N(\N=C\c4ccc(Cl)cc4...       [0, 3]
# 499007  Cc1cc(C)nc(n1)N2CCN(CN3N=C(N(\N=C\c4ccccc4[N+]...       [0, 3]
# 18                  2          24          0.7         378.036            3
# 19                  2          20         0.82         270.162            2
# 20                  2          13         0.62           172.1            2
# 21                  1          17         0.55         246.065            7
# 22                  1          15         0.69         205.074            4
# 23                  1          15         0.86         321.023            3
# 24                  2          12         0.69           160.1            2
# 25                  2          15         0.74         202.111            3
# 26                  1          16          0.9         256.044            3
# 27                  3          24         0.78         345.115            6
# 28                  1          17         0.58         246.065            7
# 29                  0          16         0.45         236.028           10
# ...               ...         ...          ...             ...          ...
# 498987              1          26         0.62         382.156            7
# 498988              4          44         0.15         654.153           10
# 498989              1          28         0.54         410.188            7
# 498990              1          28         0.57         410.188            7
# 498991              1          29         0.53         424.203            7
# 498992              1          29         0.53         424.203            7
# 498993              4          46         0.14         690.134           10
# 498994              3          32         0.33         466.131            8
# 498995              3          33          0.4         478.151            9
# 498996              3          32         0.43         462.156            8
# 498997              3          33         0.32         480.147            8
# 498998              3          34         0.39         492.167            9
# 498999              3          34          0.4         490.188            8
# 499000              3          33         0.39         496.117            8
# 499001              3          35         0.22         507.141           11
# 499002              3          33         0.41         476.172            8
# 499003              3          34         0.31         494.162            8
# 499004              3          35         0.37         506.182            9
# 499005              3          35         0.38         504.203            8
# 499006              3          34         0.38         510.133            8
# 499007              3          36         0.21         521.157           11
# 499008              3          25         0.64         337.168            4
# 499009              1          19         0.58         260.141            3
# 499010              1          10         0.44         132.058            1
# 499011              1          13         0.53         178.063            3
# 499012              0          45         0.06         638.476            8
# 499013              0          44         0.08         622.481            7
# 499014              3          26         0.71         348.147            5
# 499015              3          26         0.71         348.147            5
# 499016              3          26         0.71         348.147            5
#
#        hbd_lipinski                                            mol
# 0                 0  <rdkit.Chem.rdchem.Mol object at 0x132dcbda0>
# 1                 3  <rdkit.Chem.rdchem.Mol object at 0x132dcbf30>
# 2                 1  <rdkit.Chem.rdchem.Mol object at 0x132dcbe40>
# 3                 1  <rdkit.Chem.rdchem.Mol object at 0x132dcbee0>
# 4                 4  <rdkit.Chem.rdchem.Mol object at 0x132dcbf80>
# 5                 1  <rdkit.Chem.rdchem.Mol object at 0x132eb1170>
# 6                 1  <rdkit.Chem.rdchem.Mol object at 0x132eb1080>
# 7                 1  <rdkit.Chem.rdchem.Mol object at 0x132eb1030>
# 8                 1  <rdkit.Chem.rdchem.Mol object at 0x132eb10d0>
# 9                 4  <rdkit.Chem.rdchem.Mol object at 0x132eb11c0>
# 10                1  <rdkit.Chem.rdchem.Mol object at 0x132eb1210>
# 11                1  <rdkit.Chem.rdchem.Mol object at 0x132eb1260>
# 12                0  <rdkit.Chem.rdchem.Mol object at 0x1a1df8530>
# 13                0  <rdkit.Chem.rdchem.Mol object at 0x1a1df8580>
# 14                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df85d0>
# 15                3  <rdkit.Chem.rdchem.Mol object at 0x1a1df8620>
# 16                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df8670>
# 17                6  <rdkit.Chem.rdchem.Mol object at 0x1a1df86c0>
# 18                0  <rdkit.Chem.rdchem.Mol object at 0x1a1df8710>
# 19                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df87b0>
# 20                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df8800>
# 21                3  <rdkit.Chem.rdchem.Mol object at 0x1a1df8850>
# 22                1  <rdkit.Chem.rdchem.Mol object at 0x1a1df88a0>
# 23                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df88f0>
# 24                3  <rdkit.Chem.rdchem.Mol object at 0x1a1df8940>
# 25                2  <rdkit.Chem.rdchem.Mol object at 0x1a1df8990>
# 26                1  <rdkit.Chem.rdchem.Mol object at 0x1a1df89e0>
# 27                1  <rdkit.Chem.rdchem.Mol object at 0x1a1df8a30>
# 28                3  <rdkit.Chem.rdchem.Mol object at 0x1a1df8a80>
# 29                0  <rdkit.Chem.rdchem.Mol object at 0x1a1df8ad0>
# ...             ...                                            ...
# 498987            2  <rdkit.Chem.rdchem.Mol object at 0x139355c10>
# 498988            0  <rdkit.Chem.rdchem.Mol object at 0x139355c60>
# 498989            2  <rdkit.Chem.rdchem.Mol object at 0x139355cb0>
# 498990            2  <rdkit.Chem.rdchem.Mol object at 0x139355d00>
# 498991            2  <rdkit.Chem.rdchem.Mol object at 0x139355d50>
# 498992            2  <rdkit.Chem.rdchem.Mol object at 0x139355da0>
# 498993            0  <rdkit.Chem.rdchem.Mol object at 0x139355df0>
# 498994            0  <rdkit.Chem.rdchem.Mol object at 0x139355e40>
# 498995            0  <rdkit.Chem.rdchem.Mol object at 0x139355e90>
# 498996            0  <rdkit.Chem.rdchem.Mol object at 0x139355ee0>
# 498997            0  <rdkit.Chem.rdchem.Mol object at 0x139355f30>
# 498998            0  <rdkit.Chem.rdchem.Mol object at 0x139355f80>
# 498999            0  <rdkit.Chem.rdchem.Mol object at 0x139356030>
# 499000            0  <rdkit.Chem.rdchem.Mol object at 0x139356080>
# 499001            0  <rdkit.Chem.rdchem.Mol object at 0x1393560d0>
# 499002            0  <rdkit.Chem.rdchem.Mol object at 0x139356120>
# 499003            0  <rdkit.Chem.rdchem.Mol object at 0x139356170>
# 499004            0  <rdkit.Chem.rdchem.Mol object at 0x1393561c0>
# 499005            0  <rdkit.Chem.rdchem.Mol object at 0x139356210>
# 499006            0  <rdkit.Chem.rdchem.Mol object at 0x139356260>
# 499007            0  <rdkit.Chem.rdchem.Mol object at 0x1393562b0>
# 499008            0  <rdkit.Chem.rdchem.Mol object at 0x139356300>
# 499009            0  <rdkit.Chem.rdchem.Mol object at 0x139356350>
# 499010            0  <rdkit.Chem.rdchem.Mol object at 0x1393563a0>
# 499011            2  <rdkit.Chem.rdchem.Mol object at 0x1393563f0>
# 499012            4  <rdkit.Chem.rdchem.Mol object at 0x139356440>
# 499013            2  <rdkit.Chem.rdchem.Mol object at 0x139356490>
# 499014            1  <rdkit.Chem.rdchem.Mol object at 0x1393564e0>
# 499015            1  <rdkit.Chem.rdchem.Mol object at 0x139356530>
# 499016            1  <rdkit.Chem.rdchem.Mol object at 0x139356580>
#
# [499017 rows x 18 columns]

# %% [markdown]
# ### Save data as pickle file labeled dataset2 (all data)

# %%
data.to_pickle("./multiclass_classification/data/dataset2.pkl")

# %% [markdown]
# ### Save another dataset: dataset1 (balanced dataset with approximately equal proportion of agro and non-agrochemicals)

# %%
nonagrochemicals = shuffle(nonagrochemicals)
nonagrochemicals = nonagrochemicals[:15000]

# %%
dataset1 = pd.concat([agrochemicals, nonagrochemicals], axis=0)

# %%
dataset1
# Out:
#                                                    smiles agrochemical  \
# 487474  COc1cc2N(C)C3=C(C(=O)OC3)C(C)(c4cc(OC)c(OC)c(O...          [1]
# 487475    CN1C2=C(C(=O)OC2)C(C)(c3ccc(Cl)cc3)c4ccc(C)cc14          [1]
# 487476  CCN1C2=C(C(=O)OC2)C(C)(c3cc(OC)cc(OC)c3)c4cc5O...          [1]
# 487477  CCN1C2=C(C(=O)OC2)C(C)(c3cc(OC)cc(OC)c3)c4cc(O...          [1]
# 487478  COc1ccc2c(c1)N(C)C3=C(C(=O)OC3)C2(C)c4cc(OC)cc...          [1]
# 487479      Clc1cc(Cl)cc(c1)C2C3=C(COC3=O)Oc4cc5OCOc5cc24          [1]
# 487480          Clc1cccc(c1)C2C3=C(COC3=O)Oc4cc5OCOc5cc24          [1]
# 487481                      NC(=N)Nc1ccccc1SCc2ccc(Cl)cc2          [3]
# 487482      Clc1ccc(CSc2ccccc2N=C(NC3CCCCC3)NC4CCCCC4)cc1          [3]
# 487483                            Nc1ccccc1SCc2ccc(Cl)cc2          [3]
# 487484                             CCCCCCCCOC(=O)c1ccncc1          [3]
# 487485                               CCCCCCOC(=O)c1ccncc1          [3]
# 487486                    NC(=N)Nc1cccc(SCc2ccc(Cl)cc2)c1          [3]
# 487487    Clc1ccc(CSc2cccc(c2)N=C(NC3CCCCC3)NC4CCCCC4)cc1          [3]
# 487488           Cl.NC(=N)NC(=N)Nc1cccc(SCc2ccc(Cl)cc2)c1          [3]
# 487489                    NC(=N)Nc1ccc(SCc2ccc(Cl)cc2)cc1          [3]
# 487490    Clc1ccc(CSc2ccc(cc2)N=C(NC3CCCCC3)NC4CCCCC4)cc1          [3]
# 487491           Cl.NC(=N)NC(=N)Nc1ccc(SCc2ccc(Cl)cc2)cc1          [3]
# 487492                          Nc1ccc(SCc2ccc(Cl)cc2)cc1          [3]
# 487493                  NC(=N)Nc1ccccc1SCc2cc(Br)cc(Br)c2          [3]
# 487494  Brc1cc(Br)cc(CSc2ccccc2N=C(NC3CCCCC3)NC4CCCCC4)c1          [3]
# 487495                        Nc1ccccc1SCc2cc(Br)cc(Br)c2          [3]
# 487496                NC(=N)Nc1cccc(SCc2cc(Br)cc(Br)c2)c1          [3]
# 487497  Brc1cc(Br)cc(CSc2cccc(c2)N=C(NC3CCCCC3)NC4CCCC...          [3]
# 487498       Cl.NC(=N)NC(=N)Nc1cccc(SCc2cc(Br)cc(Br)c2)c1          [3]
# 487497              2          32         0.21         577.076            3
# 487498              2          23         0.27         454.942            5
# 487499              2          20         0.38          412.92            3
# 487500              2          32         0.21         577.076            3
# 487501              2          23         0.27         454.942            5
# 487502              2          17          0.6         370.898            1
# 487503              2          22         0.66         359.974            6
# ...               ...         ...          ...             ...          ...
# 234877              3          33         0.49         447.216            7
# 281769              2          33         0.74         469.204            7
# 183487              3          24         0.76         341.093            5
# 179818              1          17         0.52         265.034            4
# 152082              2          23         0.94         312.159            6
# 376221              1          26         0.28         381.161            6
# 368278              2          20         0.52          285.13            3
# 344494              2          17         0.86         232.101            3
# 410719              3          21         0.68         297.082            3
# 226516              2          34         0.42         491.125           10
# 46963               3          28         0.62         395.109            3
# 358047              2          28         0.79         384.168            7
# 460699              2          30         0.69         431.115            9
# 478846              1          26         0.78         356.174            6
# 481249              3          29         0.43         417.111           10
# 278304              2          35         0.53         523.181            9
# 186931              2          23         0.68         312.147            5
# 19131               2          27         0.81         360.184            4
# 250495              1          15         0.75         241.033            2
# 52684               3          23         0.54         388.024            3
# 467665              3          27         0.62         433.075            8
# 467804              3          21         0.74         297.062            2
# 273379              2          29         0.53         418.141            8
# 4476                2          30          0.5         491.077            5
# 472166              3          29         0.38         389.149            8
# 69112               3          29         0.55         411.137            8
# 144346              3          33          0.6         487.133            7
# 171912              1          20          0.9         338.099            3
# 402041              3          34         0.53         485.142            8
# 470178              2          32         0.78         438.207            7
#
#        hbd_lipinski                                            mol
# 487474            0  <rdkit.Chem.rdchem.Mol object at 0x1392678a0>
# 487475            0  <rdkit.Chem.rdchem.Mol object at 0x1392678f0>
# 487476            0  <rdkit.Chem.rdchem.Mol object at 0x139267940>
# 487477            0  <rdkit.Chem.rdchem.Mol object at 0x139267990>
# 487478            0  <rdkit.Chem.rdchem.Mol object at 0x1392679e0>
# 487479            0  <rdkit.Chem.rdchem.Mol object at 0x139267a30>
# 487480            0  <rdkit.Chem.rdchem.Mol object at 0x139267a80>
# 487481            4  <rdkit.Chem.rdchem.Mol object at 0x139267ad0>
# 487482            2  <rdkit.Chem.rdchem.Mol object at 0x139267b20>
# 487483            2  <rdkit.Chem.rdchem.Mol object at 0x139267b70>
# 487484            0  <rdkit.Chem.rdchem.Mol object at 0x139267bc0>
# 487485            0  <rdkit.Chem.rdchem.Mol object at 0x139267c10>
# 487486            4  <rdkit.Chem.rdchem.Mol object at 0x139267c60>
# 487487            2  <rdkit.Chem.rdchem.Mol object at 0x139267cb0>
# 487488            6  <rdkit.Chem.rdchem.Mol object at 0x139267d00>
# 487489            4  <rdkit.Chem.rdchem.Mol object at 0x139267d50>
# 487490            2  <rdkit.Chem.rdchem.Mol object at 0x139267da0>
# 487491            6  <rdkit.Chem.rdchem.Mol object at 0x139267df0>
# 487492            2  <rdkit.Chem.rdchem.Mol object at 0x139267e40>
# 487493            4  <rdkit.Chem.rdchem.Mol object at 0x139267e90>
# 487494            2  <rdkit.Chem.rdchem.Mol object at 0x139267ee0>
# 487495            2  <rdkit.Chem.rdchem.Mol object at 0x139267f30>
# 487496            4  <rdkit.Chem.rdchem.Mol object at 0x139267f80>
# 487497            2  <rdkit.Chem.rdchem.Mol object at 0x139268030>
# 487498            6  <rdkit.Chem.rdchem.Mol object at 0x139268080>
# 487499            4  <rdkit.Chem.rdchem.Mol object at 0x1392680d0>
# 487500            2  <rdkit.Chem.rdchem.Mol object at 0x139268120>
# 487501            6  <rdkit.Chem.rdchem.Mol object at 0x139268170>
# 487502            2  <rdkit.Chem.rdchem.Mol object at 0x1392681c0>
# 487503            1  <rdkit.Chem.rdchem.Mol object at 0x139268210>
# ...             ...                                            ...
# 234877            0  <rdkit.Chem.rdchem.Mol object at 0x137e99760>
# 281769            1  <rdkit.Chem.rdchem.Mol object at 0x138246f80>
# 183487            1  <rdkit.Chem.rdchem.Mol object at 0x137a912b0>
# 179818            1  <rdkit.Chem.rdchem.Mol object at 0x137a476c0>
# 152082            1  <rdkit.Chem.rdchem.Mol object at 0x13780ef80>
# 376221            0  <rdkit.Chem.rdchem.Mol object at 0x1389aeee0>
# 368278            0  <rdkit.Chem.rdchem.Mol object at 0x13890f940>
# 344494            1  <rdkit.Chem.rdchem.Mol object at 0x138732440>
# 410719            0  <rdkit.Chem.rdchem.Mol object at 0x138c63120>
# 226516            0  <rdkit.Chem.rdchem.Mol object at 0x137df1b70>
# 46963             1  <rdkit.Chem.rdchem.Mol object at 0x119f95bc0>
# 358047            1  <rdkit.Chem.rdchem.Mol object at 0x1388425d0>
# 460699            1  <rdkit.Chem.rdchem.Mol object at 0x13904ddf0>
# 478846            0  <rdkit.Chem.rdchem.Mol object at 0x1391ba580>
# 481249            2  <rdkit.Chem.rdchem.Mol object at 0x1391ea940>
# 278304            0  <rdkit.Chem.rdchem.Mol object at 0x138201620>
# 186931            1  <rdkit.Chem.rdchem.Mol object at 0x137ad6350>
# 19131             1  <rdkit.Chem.rdchem.Mol object at 0x118da7c10>
# 250495            0  <rdkit.Chem.rdchem.Mol object at 0x137fd3300>
# 52684             0  <rdkit.Chem.rdchem.Mol object at 0x137022bc0>
# 467665            0  <rdkit.Chem.rdchem.Mol object at 0x1390d9cb0>
# 467804            1  <rdkit.Chem.rdchem.Mol object at 0x1390dc940>
# 273379            3  <rdkit.Chem.rdchem.Mol object at 0x13819eb20>
# 4476              1  <rdkit.Chem.rdchem.Mol object at 0x1184d2a30>
# 472166            2  <rdkit.Chem.rdchem.Mol object at 0x1391342b0>
# 69112             2  <rdkit.Chem.rdchem.Mol object at 0x13716cbc0>
# 144346            1  <rdkit.Chem.rdchem.Mol object at 0x1377714e0>
# 171912            1  <rdkit.Chem.rdchem.Mol object at 0x1379a8ad0>
# 402041            2  <rdkit.Chem.rdchem.Mol object at 0x138bb4df0>
# 470178            1  <rdkit.Chem.rdchem.Mol object at 0x13910c490>
#
# [26543 rows x 18 columns]

# %%
dataset1.to_pickle("./multiclass_classification/data/dataset1.pkl")
